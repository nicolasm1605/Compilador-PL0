# %% [markdown]
# ## Compilador PL0
#
# Nicolas Moreno
#
# Kevin Oquendo

# %% [markdown]
# # Gramatica

# %% [markdown]
# programa : definicion_funcion
#           | definicion_main
#
# definicion_funcion : FUN IDENT "(" parameter_list ")" BEGIN statement_list END
#
# definicion_main : FUN MAIN "(" ")" BEGIN statement_list END
#
# parameter_list : parameter ("," parameter)*
#
# parameter : IDENT ":" TYPE ";"
#
# statement_list : statement ";" statement_list
#                   | statement
#
# statement : while_statement
#           | for_statement
#           | if_statement
#           | begin_statement
#           | assignment_statement
#           | read_statement
#           | write_statement
#           | return_statement
#           | skip_statement
#           | break_statement
#           | expression
#
# while_statement : WHILE "(" expression ")" DO statement_list END
#
# for_statement : FOR IDENT IN range_expression DO statement_list END
#
# if_statement : IF "(" expression ")" THEN statement_list ELSE statement_list END
#
# begin_statement : BEGIN statement_list END
#
# assignment_statement : IDENT ASSIGN_OP expression
#
# read_statement : READ
#
# write_statement : WRITE
#
# return_statement : RETURN expression
#
# skip_statement : SKIP
#
# break_statement : BREAK
#
# expression : term (relational_operator term)
#
# expression : term ("+" term
#                   | "-" term)*
#
# term : factor ("*" factor
#               | "/" factor)*
#
# factor : IDENT
#       | INUMBER
#       | FNUMBER
#       | "(" expression ")"
#       | UNARY
#       | BINARY
#       | STRING
#       | LOCATION
#
# range_expression : "(" expression COMA expression ")"
#
# relational_operator : EQ
#                     | NE
#                     | GT
#                     | LT
#                     | GE
#                     | LE
#
# array_expression : IDENT LBRACKET expression RBRACKET
#                   | IDENT LBRACKET expression COMA expreesion RBRACKET
#
# LBRACKET : "["
#
# RBRACKET : "]"
#
# COMA : ","
#
# DOSPUNTOS : ":"
#
# ASSIGN_OP : ":="

# %% [markdown]
# # Analizador lexico

# %%
# !pip install sly
# !pip install multimethod
# Out:
# Collecting sly
#   Downloading sly-0.5-py3-none-any.whl (28 kB)
# Installing collected packages: sly
# Successfully installed sly-0.5
# Collecting multimethod
#   Downloading multimethod-1.10-py3-none-any.whl (9.9 kB)
# Installing collected packages: multimethod
# Successfully installed multimethod-1.10

# %%
import sly
import math

# %%
from sly import Lexer

class Lexer(Lexer):
    tokens = {
        IDENT, INUMBER, FNUMBER, ASSIGN, NEWLINE, STRING,
        WHILE,FOR, DO, IF, THEN, ELSE, LOCATION, PRINT, WRITE,
        READ, RETURN, SKIP, BREAK, BEGIN, END, FUN, MAIN,
        EQ, NE, GT, LT, GE, LE, LBRACKET, RBRACKET, COMA , DOSPUNTOS
    }
    literals = '()+-*/%=^!;'

    ignore = ' \t'

    @_(r'\n+')
    def ignore_newline(self,t):
        self.lineno += t.value.count('\n')

    @_(r'\/\*(\w|\n)*(\*\/)')
    def ignore_comment(self, t):
        self.lineno += t.value.count('\n')


    @_(r'(\+|\-)?[1-9]\d*|[0]{1}\s')  # Números enteros
    def INUMBER(self, t):
        t.value = int(t.value)
        return t

    @_(r'(([1-9]((\d+\.|\.|)\d+|))((e-?|e\+?)[1-9]\d*)?)|(0\.\d+)|([0]{1}\s)')
    def FNUMBER(self, t):
        t.value = float(t.value)
        return t

    @_(r'[a-zA-Z](\w)*')  # Identificadores
    def IDENT(self, t):
        t.value = t.value
        t.type = t.value.upper()
        return t

   # Palabras clave
    WHILE = r'while'
    FOR = r'for'
    FUN = r'fun'
    MAIN = r'main'
    DO = r'do'
    IF = r'if'
    THEN = r'then'
    ELSE = r'else'
    LOCATION = r'Location'
    PRINT = r'Print'
    WRITE = r'Write'
    READ = r'Read'
    RETURN = r'Return'
    SKIP = r'skip'
    BREAK = r'break'
    BEGIN = r'begin'
    END = r'end'

    DOSPUNTOS = r':'

    # Operadores de comparación
    EQ = r'=='
    NE = r'!='
    GT = r'>'
    LT = r'<'
    GE = r'>='
    LE = r'<='

    #asignacion
    ASSIGN = r'='

    # Cadena de caracteres
    @_(r'"(?:[^"])*"')
    def STRING(self, t):
        t.value = t.value[1:-1]  # Elimina las comillas
        return t

    @_(r',')
    def COMA(self, t):
        return t

    @_(r'\[')
    def LBRACKET(self, t):
        return t

    @_(r'\]')
    def RBRACKET(self, t):
        return t

    # Nueva línea
    @_(r'\n+')
    def NEWLINE(self, t):
        self.lineno += t.value.count('\n')
        return t

    def error(self, t):
        print(f"Carácter ilegal '{t.value[0]}' en la línea {t.lineno}")
        self.index += 1

# Ejemplo de uso
lexer = Lexer()
code = '''
fun quicksort(l:int, r:int, a:int[8192])
i:int;
j:int;
x:int;
w:int;
tmp:int;
done:int;
begin
i := l;
j := r;
x := a[(l+r)/2];
done := 0;
while done == 0 do
begin
while a[i] < x do
i := i + 1;
while x < a[j] do
j := j - 1;
if i <= j then
begin
tmp := a[i];
a[i] := a[j];
a[j] := tmp;

i := i + 1;
j := j - 1
end;
if i > j then
done := 1
end;
if l < j then
tmp := quicksort(l, j, a);
if i < r then
tmp := quicksort(i, r, a)
end
fun main()
v:int[8192];
i:int;
n:int;
begin
print("Entre n: ");
read(n);
i := 0;
while i < n do
begin
read(v[i]);
i := i+1
end;
quicksort(0, n-1, v);
i := 0;
while i < n-1 do
begin
write(v[i]); print(" ");
if 0 < v[i] - v[i+1] then
begin
print("Quicksort falló "); write(i); print("\n") ; return(0)
end
else
i := i+1
end;
write(v[i]);
print("Éxito\n")
end

'''
for token in lexer.tokenize(code):
    print(token)
# Out:
# Token(type='FUN', value='fun', lineno=2, index=1, end=4)
# Token(type='QUICKSORT', value='quicksort', lineno=2, index=5, end=14)
# Token(type='(', value='(', lineno=2, index=14, end=15)
# Token(type='L', value='l', lineno=2, index=15, end=16)
# Token(type=':', value=':', lineno=2, index=16, end=17)
# Token(type='INT', value='int', lineno=2, index=17, end=20)
# Token(type=',', value=',', lineno=2, index=20, end=21)
# Token(type='R', value='r', lineno=2, index=22, end=23)
# Token(type=':', value=':', lineno=2, index=23, end=24)
# Token(type='INT', value='int', lineno=2, index=24, end=27)
# Token(type=',', value=',', lineno=2, index=27, end=28)
# Token(type='A', value='a', lineno=2, index=29, end=30)
# Token(type=':', value=':', lineno=2, index=30, end=31)
# Token(type='INT', value='int', lineno=2, index=31, end=34)
# Token(type='[', value='[', lineno=2, index=34, end=35)
# Token(type='INUMBER', value=8192, lineno=2, index=35, end=39)
# Token(type=']', value=']', lineno=2, index=39, end=40)
# Token(type=')', value=')', lineno=2, index=40, end=41)
# Token(type='I', value='i', lineno=3, index=42, end=43)
# Token(type=':', value=':', lineno=3, index=43, end=44)
# Token(type='INT', value='int', lineno=3, index=44, end=47)
# Token(type=';', value=';', lineno=3, index=47, end=48)
# Token(type='J', value='j', lineno=4, index=49, end=50)
# Token(type=':', value=':', lineno=4, index=50, end=51)
# Token(type='INT', value='int', lineno=4, index=51, end=54)
# Token(type=';', value=';', lineno=4, index=54, end=55)
# Token(type='X', value='x', lineno=5, index=56, end=57)
# Token(type=':', value=':', lineno=5, index=57, end=58)
# Token(type='INT', value='int', lineno=5, index=58, end=61)
# Token(type=';', value=';', lineno=5, index=61, end=62)
# Token(type='W', value='w', lineno=6, index=63, end=64)
# Token(type=':', value=':', lineno=6, index=64, end=65)
# Token(type='INT', value='int', lineno=6, index=65, end=68)
# Token(type=';', value=';', lineno=6, index=68, end=69)
# Token(type='TMP', value='tmp', lineno=7, index=70, end=73)
# Token(type=':', value=':', lineno=7, index=73, end=74)
# Token(type='INT', value='int', lineno=7, index=74, end=77)
# Token(type=';', value=';', lineno=7, index=77, end=78)
# Token(type='DONE', value='done', lineno=8, index=79, end=83)
# Token(type=':', value=':', lineno=8, index=83, end=84)
# Token(type='INT', value='int', lineno=8, index=84, end=87)
# Token(type=';', value=';', lineno=8, index=87, end=88)
# Token(type='BEGIN', value='begin', lineno=9, index=89, end=94)
# Token(type='I', value='i', lineno=10, index=95, end=96)
# Token(type=':', value=':', lineno=10, index=97, end=98)
# Token(type='=', value='=', lineno=10, index=98, end=99)
# Token(type='L', value='l', lineno=10, index=100, end=101)
# Token(type=';', value=';', lineno=10, index=101, end=102)
# Token(type='J', value='j', lineno=11, index=103, end=104)
# Token(type=':', value=':', lineno=11, index=105, end=106)
# Token(type='=', value='=', lineno=11, index=106, end=107)
# Token(type='R', value='r', lineno=11, index=108, end=109)
# Token(type=';', value=';', lineno=11, index=109, end=110)
# Token(type='X', value='x', lineno=12, index=111, end=112)
# Token(type=':', value=':', lineno=12, index=113, end=114)
# Token(type='=', value='=', lineno=12, index=114, end=115)
# Token(type='A', value='a', lineno=12, index=116, end=117)
# Token(type='[', value='[', lineno=12, index=117, end=118)
# Token(type='(', value='(', lineno=12, index=118, end=119)
# Token(type='L', value='l', lineno=12, index=119, end=120)
# Token(type='+', value='+', lineno=12, index=120, end=121)
# Token(type='R', value='r', lineno=12, index=121, end=122)
# Token(type=')', value=')', lineno=12, index=122, end=123)
# Token(type='/', value='/', lineno=12, index=123, end=124)
# Token(type='INUMBER', value=2, lineno=12, index=124, end=125)
# Token(type=']', value=']', lineno=12, index=125, end=126)
# Token(type=';', value=';', lineno=12, index=126, end=127)
# Token(type='DONE', value='done', lineno=13, index=128, end=132)
# Token(type=':', value=':', lineno=13, index=133, end=134)
# Token(type='=', value='=', lineno=13, index=134, end=135)
# Carácter ilegal '0' en la línea 13
# Token(type=';', value=';', lineno=13, index=137, end=138)
# Token(type='WHILE', value='while', lineno=14, index=139, end=144)
# Token(type='DONE', value='done', lineno=14, index=145, end=149)
# Token(type='EQ', value='==', lineno=14, index=150, end=152)
# Token(type='INUMBER', value=0, lineno=14, index=153, end=155)
# Token(type='DO', value='do', lineno=14, index=155, end=157)
# Token(type='BEGIN', value='begin', lineno=15, index=158, end=163)
# Token(type='WHILE', value='while', lineno=16, index=164, end=169)
# Token(type='A', value='a', lineno=16, index=170, end=171)
# Token(type='[', value='[', lineno=16, index=171, end=172)
# Token(type='I', value='i', lineno=16, index=172, end=173)
# Token(type=']', value=']', lineno=16, index=173, end=174)
# Token(type='LT', value='<', lineno=16, index=175, end=176)
# Token(type='X', value='x', lineno=16, index=177, end=178)
# Token(type='DO', value='do', lineno=16, index=179, end=181)
# Token(type='I', value='i', lineno=17, index=182, end=183)
# Token(type=':', value=':', lineno=17, index=184, end=185)
# Token(type='=', value='=', lineno=17, index=185, end=186)
# Token(type='I', value='i', lineno=17, index=187, end=188)
# Token(type='+', value='+', lineno=17, index=189, end=190)
# Token(type='INUMBER', value=1, lineno=17, index=191, end=192)
# Token(type=';', value=';', lineno=17, index=192, end=193)
# Token(type='WHILE', value='while', lineno=18, index=194, end=199)
# Token(type='X', value='x', lineno=18, index=200, end=201)
# Token(type='LT', value='<', lineno=18, index=202, end=203)
# Token(type='A', value='a', lineno=18, index=204, end=205)
# Token(type='[', value='[', lineno=18, index=205, end=206)
# Token(type='J', value='j', lineno=18, index=206, end=207)
# Token(type=']', value=']', lineno=18, index=207, end=208)
# Token(type='DO', value='do', lineno=18, index=209, end=211)
# Token(type='J', value='j', lineno=19, index=212, end=213)
# Token(type=':', value=':', lineno=19, index=214, end=215)
# Token(type='=', value='=', lineno=19, index=215, end=216)
# Token(type='J', value='j', lineno=19, index=217, end=218)
# Token(type='-', value='-', lineno=19, index=219, end=220)
# Token(type='INUMBER', value=1, lineno=19, index=221, end=222)
# Token(type=';', value=';', lineno=19, index=222, end=223)
# Token(type='IF', value='if', lineno=20, index=224, end=226)
# Token(type='I', value='i', lineno=20, index=227, end=228)
# Token(type='LT', value='<', lineno=20, index=229, end=230)
# Token(type='=', value='=', lineno=20, index=230, end=231)
# Token(type='J', value='j', lineno=20, index=232, end=233)
# Token(type='THEN', value='then', lineno=20, index=234, end=238)
# Token(type='BEGIN', value='begin', lineno=21, index=239, end=244)
# Token(type='TMP', value='tmp', lineno=22, index=245, end=248)
# Token(type=':', value=':', lineno=22, index=249, end=250)
# Token(type='=', value='=', lineno=22, index=250, end=251)
# Token(type='A', value='a', lineno=22, index=252, end=253)
# Token(type='[', value='[', lineno=22, index=253, end=254)
# Token(type='I', value='i', lineno=22, index=254, end=255)
# Token(type=']', value=']', lineno=22, index=255, end=256)
# Token(type=';', value=';', lineno=22, index=256, end=257)
# Token(type='A', value='a', lineno=23, index=258, end=259)
# Token(type='[', value='[', lineno=23, index=259, end=260)
# Token(type='I', value='i', lineno=23, index=260, end=261)
# Token(type=']', value=']', lineno=23, index=261, end=262)
# Token(type=':', value=':', lineno=23, index=263, end=264)
# Token(type='=', value='=', lineno=23, index=264, end=265)
# Token(type='A', value='a', lineno=23, index=266, end=267)
# Token(type='[', value='[', lineno=23, index=267, end=268)
# Token(type='J', value='j', lineno=23, index=268, end=269)
# Token(type=']', value=']', lineno=23, index=269, end=270)
# Token(type=';', value=';', lineno=23, index=270, end=271)
# Token(type='A', value='a', lineno=24, index=272, end=273)
# Token(type='[', value='[', lineno=24, index=273, end=274)
# Token(type='J', value='j', lineno=24, index=274, end=275)
# Token(type=']', value=']', lineno=24, index=275, end=276)
# Token(type=':', value=':', lineno=24, index=277, end=278)
# Token(type='=', value='=', lineno=24, index=278, end=279)
# Token(type='TMP', value='tmp', lineno=24, index=280, end=283)
# Token(type=';', value=';', lineno=24, index=283, end=284)
# Token(type='I', value='i', lineno=26, index=286, end=287)
# Token(type=':', value=':', lineno=26, index=288, end=289)
# Token(type='=', value='=', lineno=26, index=289, end=290)
# Token(type='I', value='i', lineno=26, index=291, end=292)
# Token(type='+', value='+', lineno=26, index=293, end=294)
# Token(type='INUMBER', value=1, lineno=26, index=295, end=296)
# Token(type=';', value=';', lineno=26, index=296, end=297)
# Token(type='J', value='j', lineno=27, index=298, end=299)
# Token(type=':', value=':', lineno=27, index=300, end=301)
# Token(type='=', value='=', lineno=27, index=301, end=302)
# Token(type='J', value='j', lineno=27, index=303, end=304)
# Token(type='-', value='-', lineno=27, index=305, end=306)
# Token(type='INUMBER', value=1, lineno=27, index=307, end=308)
# Token(type='END', value='end', lineno=28, index=309, end=312)
# Token(type=';', value=';', lineno=28, index=312, end=313)
# Token(type='IF', value='if', lineno=29, index=314, end=316)
# Token(type='I', value='i', lineno=29, index=317, end=318)
# Token(type='GT', value='>', lineno=29, index=319, end=320)
# Token(type='J', value='j', lineno=29, index=321, end=322)
# Token(type='THEN', value='then', lineno=29, index=323, end=327)
# Token(type='DONE', value='done', lineno=30, index=328, end=332)
# Token(type=':', value=':', lineno=30, index=333, end=334)
# Token(type='=', value='=', lineno=30, index=334, end=335)
# Token(type='INUMBER', value=1, lineno=30, index=336, end=337)
# Token(type='END', value='end', lineno=31, index=338, end=341)
# Token(type=';', value=';', lineno=31, index=341, end=342)
# Token(type='IF', value='if', lineno=32, index=343, end=345)
# Token(type='L', value='l', lineno=32, index=346, end=347)
# Token(type='LT', value='<', lineno=32, index=348, end=349)
# Token(type='J', value='j', lineno=32, index=350, end=351)
# Token(type='THEN', value='then', lineno=32, index=352, end=356)
# Token(type='TMP', value='tmp', lineno=33, index=357, end=360)
# Token(type=':', value=':', lineno=33, index=361, end=362)
# Token(type='=', value='=', lineno=33, index=362, end=363)
# Token(type='QUICKSORT', value='quicksort', lineno=33, index=364, end=373)
# Token(type='(', value='(', lineno=33, index=373, end=374)
# Token(type='L', value='l', lineno=33, index=374, end=375)
# Token(type=',', value=',', lineno=33, index=375, end=376)
# Token(type='J', value='j', lineno=33, index=377, end=378)
# Token(type=',', value=',', lineno=33, index=378, end=379)
# Token(type='A', value='a', lineno=33, index=380, end=381)
# Token(type=')', value=')', lineno=33, index=381, end=382)
# Token(type=';', value=';', lineno=33, index=382, end=383)
# Token(type='IF', value='if', lineno=34, index=384, end=386)
# Token(type='I', value='i', lineno=34, index=387, end=388)
# Token(type='LT', value='<', lineno=34, index=389, end=390)
# Token(type='R', value='r', lineno=34, index=391, end=392)
# Token(type='THEN', value='then', lineno=34, index=393, end=397)
# Token(type='TMP', value='tmp', lineno=35, index=398, end=401)
# Token(type=':', value=':', lineno=35, index=402, end=403)
# Token(type='=', value='=', lineno=35, index=403, end=404)
# Token(type='QUICKSORT', value='quicksort', lineno=35, index=405, end=414)
# Token(type='(', value='(', lineno=35, index=414, end=415)
# Token(type='I', value='i', lineno=35, index=415, end=416)
# Token(type=',', value=',', lineno=35, index=416, end=417)
# Token(type='R', value='r', lineno=35, index=418, end=419)
# Token(type=',', value=',', lineno=35, index=419, end=420)
# Token(type='A', value='a', lineno=35, index=421, end=422)
# Token(type=')', value=')', lineno=35, index=422, end=423)
# Token(type='END', value='end', lineno=36, index=424, end=427)
# Token(type='FUN', value='fun', lineno=37, index=428, end=431)
# Token(type='MAIN', value='main', lineno=37, index=432, end=436)
# Token(type='(', value='(', lineno=37, index=436, end=437)
# Token(type=')', value=')', lineno=37, index=437, end=438)
# Token(type='V', value='v', lineno=38, index=439, end=440)
# Token(type=':', value=':', lineno=38, index=440, end=441)
# Token(type='INT', value='int', lineno=38, index=441, end=444)
# Token(type='[', value='[', lineno=38, index=444, end=445)
# Token(type='INUMBER', value=8192, lineno=38, index=445, end=449)
# Token(type=']', value=']', lineno=38, index=449, end=450)
# Token(type=';', value=';', lineno=38, index=450, end=451)
# Token(type='I', value='i', lineno=39, index=452, end=453)
# Token(type=':', value=':', lineno=39, index=453, end=454)
# Token(type='INT', value='int', lineno=39, index=454, end=457)
# Token(type=';', value=';', lineno=39, index=457, end=458)
# Token(type='N', value='n', lineno=40, index=459, end=460)
# Token(type=':', value=':', lineno=40, index=460, end=461)
# Token(type='INT', value='int', lineno=40, index=461, end=464)
# Token(type=';', value=';', lineno=40, index=464, end=465)
# Token(type='BEGIN', value='begin', lineno=41, index=466, end=471)
# Token(type='PRINT', value='print', lineno=42, index=472, end=477)
# Token(type='(', value='(', lineno=42, index=477, end=478)
# Token(type='STRING', value='Entre n: ', lineno=42, index=478, end=489)
# Token(type=')', value=')', lineno=42, index=489, end=490)
# Token(type=';', value=';', lineno=42, index=490, end=491)
# Token(type='READ', value='read', lineno=43, index=492, end=496)
# Token(type='(', value='(', lineno=43, index=496, end=497)
# Token(type='N', value='n', lineno=43, index=497, end=498)
# Token(type=')', value=')', lineno=43, index=498, end=499)
# Token(type=';', value=';', lineno=43, index=499, end=500)
# Token(type='I', value='i', lineno=44, index=501, end=502)
# Token(type=':', value=':', lineno=44, index=503, end=504)
# Token(type='=', value='=', lineno=44, index=504, end=505)
# Carácter ilegal '0' en la línea 44
# Token(type=';', value=';', lineno=44, index=507, end=508)
# Token(type='WHILE', value='while', lineno=45, index=509, end=514)
# Token(type='I', value='i', lineno=45, index=515, end=516)
# Token(type='LT', value='<', lineno=45, index=517, end=518)
# Token(type='N', value='n', lineno=45, index=519, end=520)
# Token(type='DO', value='do', lineno=45, index=521, end=523)
# Token(type='BEGIN', value='begin', lineno=46, index=524, end=529)
# Token(type='READ', value='read', lineno=47, index=530, end=534)
# Token(type='(', value='(', lineno=47, index=534, end=535)
# Token(type='V', value='v', lineno=47, index=535, end=536)
# Token(type='[', value='[', lineno=47, index=536, end=537)
# Token(type='I', value='i', lineno=47, index=537, end=538)
# Token(type=']', value=']', lineno=47, index=538, end=539)
# Token(type=')', value=')', lineno=47, index=539, end=540)
# Token(type=';', value=';', lineno=47, index=540, end=541)
# Token(type='I', value='i', lineno=48, index=542, end=543)
# Token(type=':', value=':', lineno=48, index=544, end=545)
# Token(type='=', value='=', lineno=48, index=545, end=546)
# Token(type='I', value='i', lineno=48, index=547, end=548)
# Token(type='INUMBER', value=1, lineno=48, index=548, end=550)
# Token(type='END', value='end', lineno=49, index=551, end=554)
# Token(type=';', value=';', lineno=49, index=554, end=555)
# Token(type='QUICKSORT', value='quicksort', lineno=50, index=556, end=565)
# Token(type='(', value='(', lineno=50, index=565, end=566)
# Carácter ilegal '0' en la línea 50
# Token(type=',', value=',', lineno=50, index=567, end=568)
# Token(type='N', value='n', lineno=50, index=569, end=570)
# Token(type='INUMBER', value=-1, lineno=50, index=570, end=572)
# Token(type=',', value=',', lineno=50, index=572, end=573)
# Token(type='V', value='v', lineno=50, index=574, end=575)
# Token(type=')', value=')', lineno=50, index=575, end=576)
# Token(type=';', value=';', lineno=50, index=576, end=577)
# Token(type='I', value='i', lineno=51, index=578, end=579)
# Token(type=':', value=':', lineno=51, index=580, end=581)
# Token(type='=', value='=', lineno=51, index=581, end=582)
# Carácter ilegal '0' en la línea 51
# Token(type=';', value=';', lineno=51, index=584, end=585)
# Token(type='WHILE', value='while', lineno=52, index=586, end=591)
# Token(type='I', value='i', lineno=52, index=592, end=593)
# Token(type='LT', value='<', lineno=52, index=594, end=595)
# Token(type='N', value='n', lineno=52, index=596, end=597)
# Token(type='INUMBER', value=-1, lineno=52, index=597, end=599)
# Token(type='DO', value='do', lineno=52, index=600, end=602)
# Token(type='BEGIN', value='begin', lineno=53, index=603, end=608)
# Token(type='WRITE', value='write', lineno=54, index=609, end=614)
# Token(type='(', value='(', lineno=54, index=614, end=615)
# Token(type='V', value='v', lineno=54, index=615, end=616)
# Token(type='[', value='[', lineno=54, index=616, end=617)
# Token(type='I', value='i', lineno=54, index=617, end=618)
# Token(type=']', value=']', lineno=54, index=618, end=619)
# Token(type=')', value=')', lineno=54, index=619, end=620)
# Token(type=';', value=';', lineno=54, index=620, end=621)
# Token(type='PRINT', value='print', lineno=54, index=622, end=627)
# Token(type='(', value='(', lineno=54, index=627, end=628)
# Token(type='STRING', value=' ', lineno=54, index=628, end=631)
# Token(type=')', value=')', lineno=54, index=631, end=632)
# Token(type=';', value=';', lineno=54, index=632, end=633)
# Token(type='IF', value='if', lineno=55, index=634, end=636)
# Token(type='INUMBER', value=0, lineno=55, index=637, end=639)
# Token(type='LT', value='<', lineno=55, index=639, end=640)
# Token(type='V', value='v', lineno=55, index=641, end=642)
# Token(type='[', value='[', lineno=55, index=642, end=643)
# Token(type='I', value='i', lineno=55, index=643, end=644)
# Token(type=']', value=']', lineno=55, index=644, end=645)
# Token(type='-', value='-', lineno=55, index=646, end=647)
# Token(type='V', value='v', lineno=55, index=648, end=649)
# Token(type='[', value='[', lineno=55, index=649, end=650)
# Token(type='I', value='i', lineno=55, index=650, end=651)
# Token(type='INUMBER', value=1, lineno=55, index=651, end=653)
# Token(type=']', value=']', lineno=55, index=653, end=654)
# Token(type='THEN', value='then', lineno=55, index=655, end=659)
# Token(type='BEGIN', value='begin', lineno=56, index=660, end=665)
# Token(type='PRINT', value='print', lineno=57, index=666, end=671)
# Token(type='(', value='(', lineno=57, index=671, end=672)
# Token(type='STRING', value='Quicksort falló ', lineno=57, index=672, end=690)
# Token(type=')', value=')', lineno=57, index=690, end=691)
# Token(type=';', value=';', lineno=57, index=691, end=692)
# Token(type='WRITE', value='write', lineno=57, index=693, end=698)
# Token(type='(', value='(', lineno=57, index=698, end=699)
# Token(type='I', value='i', lineno=57, index=699, end=700)
# Token(type=')', value=')', lineno=57, index=700, end=701)
# Token(type=';', value=';', lineno=57, index=701, end=702)
# Token(type='PRINT', value='print', lineno=57, index=703, end=708)
# Token(type='(', value='(', lineno=57, index=708, end=709)
# Carácter ilegal '"' en la línea 57
# Carácter ilegal '"' en la línea 58
# Token(type=')', value=')', lineno=58, index=712, end=713)
# Token(type=';', value=';', lineno=58, index=714, end=715)
# Token(type='RETURN', value='return', lineno=58, index=716, end=722)
# Token(type='(', value='(', lineno=58, index=722, end=723)
# Carácter ilegal '0' en la línea 58
# Token(type=')', value=')', lineno=58, index=724, end=725)
# Token(type='END', value='end', lineno=59, index=726, end=729)
# Token(type='ELSE', value='else', lineno=60, index=730, end=734)
# Token(type='I', value='i', lineno=61, index=735, end=736)
# Token(type=':', value=':', lineno=61, index=737, end=738)
# Token(type='=', value='=', lineno=61, index=738, end=739)
# Token(type='I', value='i', lineno=61, index=740, end=741)
# Token(type='INUMBER', value=1, lineno=61, index=741, end=743)
# Token(type='END', value='end', lineno=62, index=744, end=747)
# Token(type=';', value=';', lineno=62, index=747, end=748)
# Token(type='WRITE', value='write', lineno=63, index=749, end=754)
# Token(type='(', value='(', lineno=63, index=754, end=755)
# Token(type='V', value='v', lineno=63, index=755, end=756)
# Token(type='[', value='[', lineno=63, index=756, end=757)
# Token(type='I', value='i', lineno=63, index=757, end=758)
# Token(type=']', value=']', lineno=63, index=758, end=759)
# Token(type=')', value=')', lineno=63, index=759, end=760)
# Token(type=';', value=';', lineno=63, index=760, end=761)
# Token(type='PRINT', value='print', lineno=64, index=762, end=767)
# Token(type='(', value='(', lineno=64, index=767, end=768)
# Carácter ilegal '"' en la línea 64
# Carácter ilegal 'É' en la línea 64
# Token(type='XITO', value='xito', lineno=64, index=770, end=774)
# Carácter ilegal '"' en la línea 65
# Token(type=')', value=')', lineno=65, index=776, end=777)
# Token(type='END', value='end', lineno=66, index=778, end=781)

# %% [markdown]
# Estructura del AST

# %%
from dataclasses import dataclass
from multimethod import multimeta


class Visitor(metaclass=multimeta):
  ...

@dataclass
class Node:
  def accept(self, v:Visitor, *args, **kwargs):
    return v.visit(self, *args, **kwargs)

@dataclass
class Expression(Node):
  ...

@dataclass
class Program(Node):
  instrucciones : list

@dataclass
class Unary(Expression):
  op : str
  expr : Expression

@dataclass
class Assign(Expression):
  IDENT : str
  expr : Expression

@dataclass
class Binary(Expression):
  op    : str
  left  : Expression
  right : Expression

@dataclass
class INumber(Expression):
  value : int

@dataclass
class FNumber(Expression):
  value : float

@dataclass
class While(Node):
    condition: Node
    stmtlist: list

@dataclass
class For(Node):
    ID: str
    start_expr: Node
    end_expr: Node
    stmtlist: list


@dataclass
class Literal(Expression):
	...
@dataclass
class StmtList(Node):
    stmtlist: list

@dataclass
class RangeExpr(Node):
    expression0: Expression
    expression1: Expression

@dataclass
class DoStmt(Node):
    stmtlist: list

@dataclass
class Param(Node):
    IDENT: str
    TYPE: str

@dataclass
class ParamList(Node):
    params: list

@dataclass
class ReturnStmt(Node):
    expr: Node

# %%
class Eval:

  @classmethod
  def eval(cls, n):
      v = cls()
      return n.accept(v)

  def visit(self, n: Program):
      lista = []
      for instruccion in n.instrucciones:
          lista.append(instruccion.accept(self))
      return lista

  def visit(self, n: INumber):
      return n.value

  def visit(self, n: FNumber):
      return n.value

  def visit(self, n: Binary):
      left = n.left.accept(self)
      right = n.right.accept(self)
      if n.op == '^':
          return eval(f"{left} ** {right}")
      else:
          return eval(f"{left} {n.op} {right}")

  def visit(self, n: Assign):
      valor = n.expr.accept(self)
      return valor

  def visit(self, n: While):
      while n.condition.accept(self):
          for stmt in n.stmtlist:
              stmt.accept(self)

  def visit(self, n: For):
      start = n.start_expr.accept(self)
      end = n.end_expr.accept(self)
      ID = n.ID
      for i in range(start, end+1):
          self.agregar(ID, i)
          for stmt in n.stmtlist:
              stmt.accept(self)

  def visit(self, n: Assign):
      valor = n.expr.accept(self)
      self.agregar(n.IDENT, valor)
      return valor

  def visit(self, n: INumber):
      return n.value

  def visit(self, n: FNumber):
      return n.value

  def visit(self, n: Binary):
      left = n.left.accept(self)
      right = n.right.accept(self)
      if n.op == '^':
          return eval(f"{left} ** {right}")
      else:
          return eval(f"{left} {n.op} {right}")

  def visit(self, n: While):
      while n.condition.accept(self):
          for stmt in n.stmtlist:
              stmt.accept(self)

  def visit(self, n: For):
      start = n.start_expr.accept(self)
      end = n.end_expr.accept(self)
      ID = n.ID
      for i in range(start, end+1):
          self.agregar(ID, i)
          for stmt in n.stmtlist:
              stmt.accept(self)
  """
  def visit(self, n: IF):
        if n.condition.accept(self):
            for stmt in n.stmtlist_true:
                stmt.accept(self)
        else:
            for stmt in n.stmtlist_false:
                stmt.accept(self)
  """
  def visit(self, n: StmtList):
      for stmt in n.stmtlist:
          stmt.accept(self)

  def visit(self, n: RangeExpr):
      start = n.expression0.accept(self)
      end = n.expression1.accept(self)
      return range(start, end+1)

  def visit(self, n: DoStmt):
      for stmt in n.stmtlist:
          stmt.accept(self)

  def visit(self, n: ParamList):
      params = []
      for param in n.params:
          params.append(param.accept(self))
      return params

  def visit(self, n: Param):
      return (n.IDENT, n.TYPE)

  def visit(self, n: ReturnStmt):
        return n.expression.accept(self)

# %%
from graphviz import Digraph

class Dot(Visitor):
  node_default = {
      'shape' : 'box',
      'color' : 'cyan',
      'style' : 'filled'
  }
  edge_default = {
      'arrowhead' : 'none',
  }

  def __init__(self):
    self.dot = Digraph('AST')
    self.dot.attr('node', **self.node_default)
    self.dot.attr('edge', **self.edge_default)
    self.seq = 0

  def __str__(self):
    return self.dot.source

  def __repr__(self):
    return self.dot.source

  def name(self):
    self.seq += 1
    return f'n{self.seq:0d}'

  @classmethod
  def render(cls, n:Node):
    dot = cls()
    n.accept(dot)
    return dot.dot
  def visit(self, n:Program):
    name = self.name()
    self.dot.node(name, label=f'Programa')
    for instruccion in n.instrucciones:
      self.dot.edge(name,instruccion.accept(self))


  def visit(self, n:INumber):
    name = self.name()
    self.dot.node(name, label=f'{n.value}')
    return name

  def visit(self, n:FNumber):
    name = self.name()
    self.dot.node(name, label=f'{n.value}')
    return name

  def visit(self, n:Unary):
    name = self.name()
    self.dot.node(name, label=f'{n.op}', shape='circle', color='darkseagreen1')
    self.dot.edge(name, n.expr.accept(self))
    return name

  def visit(self, n:Binary):
    name = self.name()
    self.dot.node(name, label=f'{n.op}', shape='circle', color='darkseagreen1')
    self.dot.edge(name, n.left.accept(self))
    self.dot.edge(name, n.right.accept(self))
    return name

  def visit(self, n:Assign):
    name = self.name()
    self.dot.node(name, label=f'=', shape='circle', color='darkseagreen1')
    self.dot.edge(name, n.IDENT)
    self.dot.edge(name, n.expr.accept(self))
    return name


  def visit(self, n: While):
        name = self.name()
        self.dot.node(name, label='While', shape='box', color='cyan', style='filled')
        self.dot.edge(name, n.condition.accept(self))
        for stmt in n.stmtlist:
            self.dot.edge(name, stmt.accept(self))
        return name

  def visit(self, n: For):
      name = self.name()
      self.dot.node(name, label='For', shape='box', color='cyan', style='filled')
      self.dot.edge(name, n.start_expr.accept(self))
      self.dot.edge(name, n.end_expr.accept(self))
      self.dot.edge(name, n.ID)
      for stmt in n.stmtlist:
          self.dot.edge(name, stmt.accept(self))
      return name
  """
  def visit(self, n: If):
      name = self.name()
      self.dot.node(name, label='If', shape='box', color='cyan', style='filled')
      self.dot.edge(name, n.condition.accept(self))
      for stmt in n.stmtlist_true:
          self.dot.edge(name, stmt.accept(self))
      for stmt in n.stmtlist_false:
          self.dot.edge(name, stmt.accept(self))
      return name
  """
  def visit(self, n: StmtList):
      name = self.name()
      self.dot.node(name, label='StmtList', shape='box', color='cyan', style='filled')
      for stmt in n.stmtlist:
          self.dot.edge(name, stmt.accept(self))
      return name

  def visit(self, n: RangeExpr):
      name = self.name()
      self.dot.node(name, label='RangeExpr', shape='box', color='cyan', style='filled')
      self.dot.edge(name, n.expression0.accept(self))
      self.dot.edge(name, n.expression1.accept(self))
      return name

  def visit(self, n: DoStmt):
      name = self.name()
      self.dot.node(name, label='DoStmt', shape='box', color='cyan', style='filled')
      for stmt in n.stmtlist:
          self.dot.edge(name, stmt.accept(self))
      return name

  def visit(self, n: ParamList):
      name = self.name()
      self.dot.node(name, label='ParamList', shape='box', color='cyan', style='filled')
      for param in n.params:
          self.dot.edge(name, param.accept(self))
      return name

  def visit(self, n: Param):
      name = self.name()
      self.dot.node(name, label=f'Param\n{str(n)}', shape='box', color='cyan', style='filled')
      return name

  def visit(self, n: ReturnStmt):
      name = self.name()
      self.dot.node(name, label='ReturnStmt', shape='box', color='cyan', style='filled')
      self.dot.edge(name, n.expr.accept(self))
      return name

# %% [markdown]
# # Analizador sintactico

# %%
class Parser(sly.Parser):
    debugfile = 'eval.txt'  # Correr el programa
    tokens = Lexer.tokens

    def __init__(self):
        self.mem_dict = {}

    def agregar(self, IDENT, expr):
        self.mem_dict[IDENT] = expr

    def sacar_valor(self, IDENT):
        return self.mem_dict.get(IDENT)

    @_('stmtlist')
    def programa(self, p):
        return Program(p.stmtlist)

    @_('stmtlist ";" stmt')
    def stmtlist(self, p):
        p.stmtlist.append(p.stmt)
        return p.stmtlist

    @_('stmt')
    def stmtlist(self, p):
        return [p.stmt]

    @_('FUN IDENT "(" param_list ")" BEGIN stmtlist END')
    def FUN(self, p):
        return Funcion(p.IDENT, p.param_list, p.stmtlist)

    @_('MAIN "(" ")" BEGIN stmtlist END')
    def MAIN(self, p):
        return Funcion("main", [], p.stmtlist)

    @_('param_list "," param')
    def param_list(self, p):
        return p.param_list + [p.param]

    @_('param')
    def param_list(self, p):
        return [p.param]

    @_('IDENT ":" TYPE ";"')
    def param(self, p):
        return (p.IDENT, p.TYPE)

    @_("ASSIGN")
    def ASSIGN(self, IDENT, expr):
      self.agregar(IDENT, expr)
      return ASSIGN(IDENT, expr)

    @_('IDENT')
    def param(self, p):
        return (p.IDENT,)

    @_('while_stmt')
    def stmt(self, p):
        return p.while_stmt

    @_('for_stmt')
    def stmt(self, p):
        return p.for_stmt

    @_('if_stmt')
    def stmt(self, p):
        return p.if_stmt

    @_('begin_stmt')
    def stmt(self, p):
        return p.begin_stmt

    @_('BEGIN stmtlist END')
    def begin_stmt(self, p):
        return p.stmtlist

    @_('IF "(" expression ")" THEN stmtlist ELSE stmtlist END')
    def if_stmt(self, p):
        return If(p.expression, p.stmtlist0, p.stmtlist1)

    @_('WHILE "(" expression ")" DO stmtlist END')
    def while_stmt(self, p):
        return While(p.expression, p.stmtlist)

    @_('FOR IDENT IN range_expr DO stmtlist END')
    def for_stmt(self, p):
        return For(p.IDENT, p.range_expr[0], p.range_expr[1], p.stmtlist)

    @_("FOR IDENT IN range_expr DOSPUNTOS stmtlist END")
    def For(self, p):
        return For(p.IDENT, p.range_expr[0], p.range_expr[1], p.stmtlist)

    @_("WHILE '(' expression ')' DOSPUNTOS stmtlist END")
    def While(self, p):
        return While(p.expression, p.stmtlist)

    @_('"(" expression "," expression ")"')
    def range_expr(self, p):
        return (p.expression0, p.expression1)

    @_("term '+' expr",
       "term '-' expr")
    def expr(self, p):
        return Binary(p[1], p.term, p.expr)

    @_("term")
    def expr(self, p):
        return p.term

    @_("factor '*' term",
       "factor '/' term")
    def term(self, p):
        return Binary(p[1], p.factor, p.term)

    @_('STRING')
    def STRING(self, p):
        string_value = p.STRING[1:-1]
        return STRING(string_value)

    @_("expr GT expr",
      "expr LT expr",
      "expr EQ expr",
      "expr NE expr",
      "expr GE expr",
      "expr LE expr")
    def expression(self, p):
        return Binary(p[2], p.expr0, p.expr1)

    @_("factor")
    def term(self, p):
        return p.factor

    @_("INUMBER")
    def factor(self, p):
        return INumber(p.INUMBER)

    @_("FNUMBER")
    def factor(self, p):
        return FNumber(p.FNUMBER)

    @_('DOSPUNTOS')
    def DOSPUNTOS(self, p):
        pass

    @_("expr")
    def stmt(self, p):
        return p.expr

    @_("IDENT '=' expr")
    def stmt(self, p):
        self.agregar(p.IDENT, p.expr)
        return Assign(p.IDENT, p.expr)

    @_("IDENT")
    def factor(self, p):
        return self.sacar_valor(p.IDENT)

    @_("'(' expr ')'")
    def factor(self, p):
        return p.expr

    @_('BREAK')
    def BREAK(self, p):
        return BREAK()

    @_('RETURN expr')
    def return_stmt(self, p):
        return Return(p.expr)

    @_('PRINT "(" expr ")"')
    def PRINT(self, p):
        return PRINT(p.expr)

    @_('LOCATION "(" STRING ")"')
    def LOCATION(self, p):
        return LOCATION(p.STRING)

    @_('READ "(" IDENT ")"')
    def read(self, p):
        variable_name = p.IDENT
        return Read(variable_name)

    @_('WRITE "(" expr ")"')
    def write(self, p):
        expression = p.expr
        return Write(expression)

    @_('SKIP')
    def skip(self, p):
        return Skip()

    @_('NEWLINE')
    def newline(self, p):
        pass
# Out:
# WARNING: Token(s) {FLOAT,PRINT,FUN,OR,BREAK,AND,ID,ASSIGN,INT,LOCATION,STRING,NOT} defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:88: Rule 'For' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:92: Rule 'While' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:165: Rule 'return_stmt' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:177: Rule 'read' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:182: Rule 'write' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:187: Rule 'skip' defined, but not used
# WARNING: <ipython-input-16-e5a073e07a24>:191: Rule 'newline' defined, but not used
# WARNING: There are 12 unused tokens
# WARNING: There are 7 unused rules
# WARNING: Symbol 'MAIN' is unreachable
# WARNING: Symbol 'param_list' is unreachable
# WARNING: Symbol 'param' is unreachable
# WARNING: Symbol 'TYPE' is unreachable
# WARNING: Symbol 'For' is unreachable
# WARNING: Symbol 'DOSPUNTOS' is unreachable
# WARNING: Symbol 'While' is unreachable
# WARNING: Symbol 'return_stmt' is unreachable
# WARNING: Symbol 'read' is unreachable
# WARNING: Symbol 'write' is unreachable
# WARNING: Symbol 'skip' is unreachable
# WARNING: Symbol 'newline' is unreachable
# ---------------------------------------------------------------------------
# YaccError                                 Traceback (most recent call last)
# <ipython-input-16-e5a073e07a24> in <cell line: 1>()
# ----> 1 class Parser(sly.Parser):
#       2     debugfile = 'eval.txt'  # Correr el programa
#       3     tokens = Lexer.tokens
#       4
#       5     def __init__(self):
#
# /usr/local/lib/python3.10/dist-packages/sly/yacc.py in __new__(meta, clsname, bases, attributes)
#    1818         del attributes['_']
#    1819         cls = super().__new__(meta, clsname, bases, attributes)
# -> 1820         cls._build(list(attributes.items()))
#    1821         return cls
#    1822
#
# /usr/local/lib/python3.10/dist-packages/sly/yacc.py in _build(cls, definitions)
#    2015
#    2016         # Build the underlying grammar object
# -> 2017         cls.__build_grammar(rules)
#    2018
#    2019         # Build the LR tables
#
# /usr/local/lib/python3.10/dist-packages/sly/yacc.py in __build_grammar(cls, rules)
#    1961         cls._grammar = grammar
#    1962         if errors:
# -> 1963             raise YaccError('Unable to build grammar.\n'+errors)
#    1964
#    1965     @classmethod
#
# YaccError: Unable to build grammar.
# <ipython-input-16-e5a073e07a24>:27: Illegal rule name 'FUN'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:47: Illegal rule name 'ASSIGN'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:114: Illegal rule name 'STRING'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:161: Illegal rule name 'BREAK'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:169: Illegal rule name 'PRINT'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:173: Illegal rule name 'LOCATION'. Already defined as a token
# <ipython-input-16-e5a073e07a24>:52: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:43: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:43: Symbol 'TYPE' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:148: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:84: Symbol 'FOR' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:84: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:84: Symbol 'IN' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:88: Symbol 'FOR' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:88: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:88: Symbol 'IN' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:153: Symbol 'IDENT' used, but not defined as a token or a rule
# <ipython-input-16-e5a073e07a24>:177: Symbol 'IDENT' used, but not defined as a token or a rule

# %%
code = 'a = 1 + 2 * 3 / 4'
lex = Lexer()
pas = Parser()
a=(lex.tokenize(code))
for tok in a:
  print(tok)
ast = pas.parse(lex.tokenize(code))
print(ast)
Dot.render(ast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-54b65cb65175> in <cell line: 3>()
#       1 code = 'a = 1 + 2 * 3 / 4'
#       2 lex = Lexer()
# ----> 3 pas = Parser()
#       4 a=(lex.tokenize(code))
#       5 for tok in a:
#
# NameError: name 'Parser' is not defined

# %% [markdown]
# # Analizador Semantico

# %%
class Symtab:
  '''
  Una tabla de símbolos.  Este es un objeto simple que sólo
  mantiene una hashtable (dict) de nombres de simbolos y los
  nodos de declaracion o definición de funciones a los que se
  refieren.
  Hay una tabla de simbolos separada para cada elemento de
  código que tiene su propio contexto (por ejemplo cada función,
  clase, tendra su propia tabla de simbolos). Como resultado,
  las tablas de simbolos se pueden anidar si los elementos de
  código estan anidados y las búsquedas de las tablas de
  simbolos se repetirán hacia arriba a través de los padres
  para representar las reglas de alcance léxico.
  '''
  class SymbolDefinedError(Exception):
    '''
    Se genera una excepción cuando el código intenta agregar
    un simbol a una tabla donde el simbol ya se ha definido.
    Tenga en cuenta que 'definido' se usa aquí en el sentido
    del lenguaje C, es decir, 'se ha asignado espacio para el
    simbol', en lugar de una declaración.
    '''
    pass

  def __init__(self, parent=None):
    '''
    Crea una tabla de símbolos vacia con la tabla de
    simbolos padre dada.
    '''
    self.entries = {}
    self.parent = parent
    if self.parent:
      self.parent.children.append(self)
    self.children = []

  def add(self, name, value):
    '''
    Agrega un simbol con el valor dado a la tabla de simbolos.
    El valor suele ser un nodo AST que representa la declaración
    o definición de una función, variable (por ejemplo, Declaración
    o FuncDeclaration)
    '''
    if name in self.entries:
      raise Symtab.SymbolDefinedError()
    self.entries[name] = value

  def get(self, name):
    '''
    Recupera el símbol con el nombre dado de la tabla de
    simbol, recorriendo hacia arriba a traves de las tablas
    de simbol principales si no se encuentra en la actual.
    '''
    if name in self.entries:
      return self.entries[name]
    elif self.parent:
      return self.parent.get(name)
    return None

# %%
class Checker(Visitor):

    def visit(self, n: Literal, env: Symtab):
      # Devolver datatype
        return n.datatype

    def visit(self, n: Location, env: Symtab):
      # Buscar en Symtab y extraer datatype (No se encuentra?)
		# Devuelvo el datatype
        datatype = env.get(n.IDENT)
        if not datatype:
            raise NameError(f"La variable {n.IDENT} no está definida")
        return datatype

    def visit(self, n: TypeCast, env: Symtab):
      # Visitar la expresion asociada
		# Devolver datatype asociado al nodo
        expr_datatype = n.expr.accept(self, env)
        if n.TYPE != expr_datatype:
            raise TypeError(f"Error de tipo en la conversión: {n.TYPE} y {expr_datatype}")
        return n.TYPE

    def visit(self, n: Assign, env: Symtab):
      # Visitar el hijo izquierdo (devuelve datatype)
		# Visitar el hijo derecho (devuelve datatype)
		# Comparar ambos tipo de datatype
        left_datatype = n.left.accept(self, env)
        right_datatype = n.right.accept(self, env)

        if left_datatype != right_datatype:
            raise TypeError(f"Tipos incompatibles en la asignación: {left_datatype} y {right_datatype}")

        return left_datatype

    def visit(self, n: FuncCall, env: Symtab):
      # Buscar la funcion en Symtab (extraer: Tipo de retorno, el # de parametros)
		# Visitar la lista de Argumentos
		# Comparar el numero de argumentos con parametros
		# Comparar cada uno de los tipos de los argumentos con los parametros
		# Retornar el datatype de la funcion
        func = env.get(n.IDENT)
        if not func or not isinstance(func, FuncDefinition):
            raise NameError(f"La función {n.IDENT} no está definida")

        if len(n.arglist) != len(func.paramlist):
            raise TypeError(f"Número incorrecto de argumentos para la función {n.IDENT}")

        for arg, param in zip(n.arglist, func.paramlist):
            arg_type = arg.accept(self, env)
            if arg_type != param.TYPE:
                raise TypeError(f"Tipo incorrecto para el argumento en la llamada a la función {n.IDENT}")

        return func.return_type

    def visit(self, n: Binary, env: Symtab):
      # Visitar el hijo izquierdo (devuelve datatype)
		# Visitar el hijo derecho (devuelve datatype)
		# Comparar ambos tipo de datatype
        left_datatype = n.left.accept(self, env)
        right_datatype = n.right.accept(self, env)

        if n.op in {'+', '-', '*', '/'}:
            if left_datatype not in {'int', 'float'} or right_datatype not in {'int', 'float'}:
                raise TypeError(f"Operación no válida para tipos {left_datatype} y {right_datatype}")
            if left_datatype == 'int' and right_datatype == 'int':
                return 'int'
            else:
                return 'float'
        elif n.op == '^':
            if left_datatype != 'int' or right_datatype != 'int':
                raise TypeError(f"Operación no válida para tipos {left_datatype} y {right_datatype}")
            return 'int'
        else:
            raise ValueError(f"Operador no reconocido: {n.op}")

    def visit(self, n: Logical, env: Symtab):
      # Visitar el hijo izquierdo (devuelve datatype)
		# Visitar el hijo derecho (devuelve datatype)
		# Comparar ambos tipo de datatype
        left_datatype = n.left.accept(self, env)
        right_datatype = n.right.accept(self, env)

        if n.op in {'and', 'or'}:
            if left_datatype != 'bool' or right_datatype != 'bool':
                raise TypeError(f"Operación no válida para tipos {left_datatype} y {right_datatype}")
            return 'bool'
        else:
            raise ValueError(f"Operador lógico no reconocido: {n.op}")

    def visit(self, n: Unary, env: Symtab):
      # Visitar la expression asociada (devuelve datatype)
		# Comparar datatype
        expr_datatype = n.expr.accept(self, env)
        if n.op == '!':
            if expr_datatype != 'int':
                raise TypeError(f"Operación no válida para tipo {expr_datatype}")
            return 'int'
        else:
            raise ValueError(f"Operador unario no reconocido: {n.op}")

    def visit(self, n: FuncDefinition, env: Symtab):
        # Agregar el nombre de la funcion a Symtab
		# Crear un nuevo contexto (Symtab)
		# Visitar ParamList, VarList, StmtList
		# Determinar el datatype de la funcion (revisando instrucciones return)
        env.add(n.IDENT, n)
        # Crea un nuevo contexto (Symtab)
        local_env = Symtab(parent=env)
        # Visitar ParamList, VarList, StmtList
        for param in n.paramlist:
            param.accept(self, local_env)
        for var in n.varlist:
            var.accept(self, local_env)
        n.stmtlist.accept(self, local_env)
        # Determinar el datatype de la función (revisando instrucciones return)
        return_type = None
        for stmt in n.stmtlist:
            if isinstance(stmt, Return):
                return_type = stmt.accept(self, local_env)
        n.return_type = return_type

    def visit(self, n: VarDefinition, env: Symtab):
        # Agrega la lógica para manejar la definición de variables
        env.add(n.IDENT, n.TYPE)

    def visit(self, n: Parameter, env: Symtab):
       # Agregar el nombre del parametro a Symtab
        env.add(n.IDENT, n.TYPE)

    def visit(self, n: Print, env: Symtab):
        expr_datatype = n.expr.accept(self, env)
        if expr_datatype not in {'int', 'float', 'string'}:
            raise TypeError(f"Tipo no válido para la instrucción print: {expr_datatype}")

    def visit(self, n: Write, env: Symtab):
        # Buscar la Variable en Symtab
        expr_datatype = n.location.accept(self, env)
        if expr_datatype not in {'int', 'float'}:
            raise TypeError(f"Tipo no válido para la instrucción write: {expr_datatype}")

    def visit(self, n: Read, env: Symtab):
        # Buscar la Variable en Symtab
        location_datatype = n.location.accept(self, env)
        if location_datatype not in {'int', 'float'}:
            raise TypeError(f"Tipo no válido para la instrucción read: {location_datatype}")

    def visit(self, n: While, env: Symtab):
        # Visitar la condicion del While (Comprobar tipo bool)
		  # Visitar las Stmts
        condition_datatype = n.condition.accept(self, env)

        # Verificar que la condición sea de tipo bool
        if condition_datatype != 'bool':
            raise TypeError(f"La condición del bucle 'while' debe ser de tipo 'bool', no {condition_datatype}")

        # Crear un nuevo entorno para las instrucciones dentro del bucle
        while_env = Symtab(parent=env)

        # Visitar las instrucciones dentro del bucle con el nuevo entorno
        n.stmtlist.accept(self, while_env)

    def visit(self, n: Break, env: Symtab):
        # Esta dentro de un While?
        current_env = env
        while current_env:
            if isinstance(current_env.entries.get('loop'), While):
                return
            current_env = current_env.parent
        raise ValueError("La instrucción 'break' debe estar dentro de un bucle 'while'")

    def visit(self, n: IfStmt, env: Symtab):
        # Visitar la condicion del IfStmt (Comprobar tipo bool)
		    # Visitar las Stmts del then y else
        condition_datatype = n.condition.accept(self, env)
        if condition_datatype != 'bool':
            raise TypeError(f"Tipo no válido para la condición del IfStmt: {condition_datatype}")

        # Stmts del 'then' y 'else'
        n.stmtlist_then.accept(self, env)
        if n.stmtlist_else:
            n.stmtlist_else.accept(self, env)

    def visit(self, n: Return, env: Symtab):
        # Visitar la expresion asociada
		# Actualizar el datatype de la funcion
        expr_datatype = n.expr.accept(self, env)

        func_def = env.get('current_function')
        if func_def:
            if not func_def.return_type:
                func_def.return_type = expr_datatype
            else:
                if func_def.return_type != expr_datatype:
                    raise TypeError(f"Tipo de retorno incompatible para la función {func_def.IDENT}")

    def visit(self, n: Skip, env: Symtab):
        pass

    def visit(self, n: Program, env: Symtab):
        # Crear un nuevo contexto (Symtab global)
		# Visitar cada una de las declaraciones asociadas
        global_env = Symtab(parent=None)
        n.symtab = global_env
        #visitar cada una de las declaraciones asociadas
        for declaration in n.declarations:
            declaration.accept(self, global_env)

    def visit(self, n: StmtList, env: Symtab):
        # Visitar cada una de las instruciones asociadas
        for stmt in n.stmts:
            stmt.accept(self, env)

    def visit(self, n: VarList, env: Symtab):
        # Visitar cada una de las variables asociadas
        for var in n.vars:
            var.accept(self, env)

    def visit(self, n: ParmList, env: Symtab):
        # Visitar cada una de los parametros asociados
        for param in n.params:
            param.accept(self, env)

    def visit(self, n: ArgList, env: Symtab):
        # Visitar cada una de los argumentos asociados
        for arg in n.args:
            arg.accept(self, env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-ccd7a552da3f> in <cell line: 1>()
# ----> 1 class Checker(Visitor):
#       2
#       3     def visit(self, n: Literal, env: Symtab):
#       4       # Devolver datatype
#       5         return n.datatype
#
# <ipython-input-18-ccd7a552da3f> in Checker()
#       5         return n.datatype
#       6
# ----> 7     def visit(self, n: Location, env: Symtab):
#       8       # Buscar en Symtab y extraer datatype (No se encuentra?)
#       9                 # Devuelvo el datatype
#
# NameError: name 'Location' is not defined

# %%
from rich import print

# %%
code = 'a = 1 + 2 * 3 / 4'
lex = Lexer()
pas = Parser()
a=(lex.tokenize(code))
for tok in a:
  print(tok)
ast = pas.parse(lex.tokenize(code))
print(ast)
Dot.render(ast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-54b65cb65175> in <cell line: 2>()
#       1 code = 'a = 1 + 2 * 3 / 4'
# ----> 2 lex = Lexer()
#       3 pas = Parser()
#       4 a=(lex.tokenize(code))
#       5 for tok in a:
#
# NameError: name 'Lexer' is not defined

# %%
code = 'a = 1 + 2 * 3 / 4; a / 2; b = sin(3*pi/8) + a'

lex = Lexer()
pas = Parser()
a=(lex.tokenize(code))
for tok in a:
  print(tok)
ast = pas.parse(lex.tokenize(code))
print(ast)
check = Checker()
symtab = Symtab()
check.visit(ast, symtab)
Dot.render(ast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b4b284b84fc2> in <cell line: 4>()
#       2
#       3 lex = Lexer()
# ----> 4 pas = Parser()
#       5 a=(lex.tokenize(code))
#       6 for tok in a:
#
# NameError: name 'Parser' is not defined

# %%
def main(argv):
    if len(argv) != 2:
        print(f"Usage: python {argv[0]} filename")
        exit(1)

    lex = Lexer()
    txt = open(argv[1]).read()

    for tok in lex.tokenize(txt):
        print(tok)


if __name__ == '__main__':
    from sys import argv
    main(argv)
